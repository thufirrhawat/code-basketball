# %%
from os import path
import pandas as pd
DATA_DIR = r"C:\Users\Nurettin Ünal\Desktop\Stuff\code-basketball-files-main\data"

# %%
#3.0.1
games = pd.read_csv(path.join(DATA_DIR, 'games.csv'))
#3.0.2
game50 = games.sort_values('date').head(50)
#3.0.3
print(type(games.sort_values('home_pts', ascending=False)))
#3.0.4
game50.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     game_id home away        date  home_pts  away_pts  min  home_fgm
# 0  21900001  TOR  NOP  2019-10-22       130       122  265        42  \
# 1  21900002  LAC  LAL  2019-10-22       112       102  239        42
# 2  21900003  CHA  CHI  2019-10-23       126       125  240        45
# 3  21900004  IND  DET  2019-10-23       110       119  241        41
# 4  21900005  ORL  CLE  2019-10-23        94        85  239        37
#
#    home_fga  home_fg_pct  ...  away_reb  away_ast  away_stl  away_blk
# 0       103        0.408  ...        53        30         4         9  \
# 1        81        0.519  ...        41        20         4         7
# 2        88        0.511  ...        49        25        11         4
# 3        89        0.461  ...        45        26         5         6
# 4        86        0.430  ...        54        20         8         2
#
#    away_tov  away_pf  away_plus_minus  bubble  sample   season
# ...

# %%
#3.0.5
game_simple = games[['date','home','away','home_pts','away_pts']] #a
game_simple = games[['home','away','date','home_pts','away_pts']] #b
game_simple['game_id'] = games['game_id'] #c
game_simple.to_csv(path.join(DATA_DIR, 'game_simple.csv'),sep='|') #d
# Out:
# C:\Users\Nurettin Ünal\AppData\Local\Temp\ipykernel_10988\3823948064.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   game_simple['game_id'] = games['game_id'] #c
